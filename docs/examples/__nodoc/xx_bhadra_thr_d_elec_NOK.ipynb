# %% [markdown]
# # Example 16: KES Block thresholds with PSA electrode
#
# This script evaluates the KES block threshold of myelinated fibers when stimulated with a PSA electrode. It is a close replication of results published by Bhadra et al (2006).

# %%
import sys
sys.path.append("../")
import nrv
import matplotlib.pyplot as plt
import numpy as np

#nrv.parameters.set_nrv_verbosity(2)

t_sim = 20                  		#Simulation Duration [ms]

# axon def
y_a = 0								# axon y position, in [um]
z_a = 0								# axon z position, in [um]
N_node = 51                 		# 21 nodes of Ranvier   -- was 51 in orignal paper
model = 'MRG'						#Myelinated Axon model
material =  'endoneurium_bhadra'    #material for the endoneurium

# test pulse
t_start = t_sim-5   						# Test pulse start, in [ms]
t_duration = 0.1						# Test pulse duration, in [ms]
t_amplitude = 5						# Test pulse amplitude, in [nA]

#Axon ranges from 2µm to 20µm
d_min = 2
d_max = 20
n_diam = 10
d_axon_list = np.round(np.linspace(d_min,d_max,num=n_diam))


d_elect = 100				#Electrode Distance list, in [um]
max_amp = 100		        #Max KES amplitude for the Binary search

KES_freq = 10                           #KES block frequency list, in [kHz]			
amp_tol = 5								#Amplitude tolerance for the search, in %

dt = 0.005

stim = nrv.stimulus()                     #dummy stim
stim_extra = nrv.stimulation(material)      #analytical stimulation, no FEM

for diam in d_axon_list:
    print(f"Axon diameter: {diam}µm")
    threshold_list= []
    L = nrv.get_length_from_nodes(diam,N_node)	#Return L of myelinated axon for a given number of NoR, in [um]

    axon1 = nrv.myelinated(y=y_a,z=z_a,d=diam, L=L, rec="nodes",model=model)
    n_node = len(axon1.x_nodes)
    x_elec = axon1.x_nodes[n_node//2]
    elec_1 = nrv.point_source_electrode(x_elec, d_elect, 0)
    stim_extra.add_electrode(elec_1, stim)        
    axon1.attach_extracellular_stimulation(stim_extra)

    threshold = nrv.blocking_threshold_from_axon(axon1,block_freq = KES_freq, amp_max  =max_amp,
                                             amp_tol = amp_tol,t_sim= t_sim,t_start=t_start,
                                             t_duration = t_duration, t_amplitude = t_amplitude,
                                             b_start = 1)
    
    print ("Block Threshold is: " + str(int(threshold)) +"uA.")
    threshold_list.append(threshold)
    del axon1
# Out:
# Axon diameter: 2.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 9.084656238555908 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 2, testing block current amplitude 0 uA
# NRV INFO: ... Iteration simulation performed in 8.743825197219849 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 3, testing block current amplitude 300.0 uA
# NRV INFO: ... Iteration simulation performed in 8.280965089797974 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 4, testing block current amplitude 150.0 uA
# NRV INFO: ... Iteration simulation performed in 8.675652265548706 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 5, testing block current amplitude 75.0 uA
# NRV INFO: ... Iteration simulation performed in 9.020358085632324 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 6, testing block current amplitude 37.5 uA
# NRV INFO: ... Iteration simulation performed in 9.448361158370972 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 7, testing block current amplitude 18.75 uA
# NRV INFO: ... Iteration simulation performed in 8.483375072479248 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 8, testing block current amplitude 28.125 uA
# NRV INFO: ... Iteration simulation performed in 8.309462070465088 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 9, testing block current amplitude 32.8125 uA
# NRV INFO: ... Iteration simulation performed in 8.0767822265625 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 10, testing block current amplitude 35.15625 uA
# NRV INFO: ... Iteration simulation performed in 8.15519380569458 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 11, testing block current amplitude 33.984375 uA
# NRV INFO: ... Iteration simulation performed in 8.445718050003052 s
# NRV INFO: ... Spike not blocked
# Block Threshold is: 34uA.
# Axon diameter: 4.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 8.615580320358276 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 2, testing block current amplitude 0 uA
# NRV INFO: ... Iteration simulation performed in 8.148157119750977 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 3, testing block current amplitude 300.0 uA
# NRV INFO: ... Iteration simulation performed in 8.329792976379395 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 4, testing block current amplitude 150.0 uA
# NRV INFO: ... Iteration simulation performed in 8.310712814331055 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 5, testing block current amplitude 75.0 uA
# NRV INFO: ... Iteration simulation performed in 8.210484027862549 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 6, testing block current amplitude 37.5 uA
# NRV INFO: ... Iteration simulation performed in 8.283512115478516 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 7, testing block current amplitude 18.75 uA
# NRV INFO: ... Iteration simulation performed in 8.544452905654907 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 8, testing block current amplitude 28.125 uA
# NRV INFO: ... Iteration simulation performed in 8.485029220581055 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 9, testing block current amplitude 32.8125 uA
# NRV INFO: ... Iteration simulation performed in 9.365602254867554 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 10, testing block current amplitude 30.46875 uA
# NRV INFO: ... Iteration simulation performed in 9.257544994354248 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 11, testing block current amplitude 29.296875 uA
# NRV INFO: ... Iteration simulation performed in 8.94471287727356 s
# NRV INFO: ... Spike not blocked
# Block Threshold is: 29uA.
# Axon diameter: 6.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 10.793947219848633 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 2, testing block current amplitude 0 uA
# NRV INFO: ... Iteration simulation performed in 9.401794910430908 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 3, testing block current amplitude 300.0 uA
# NRV INFO: ... Iteration simulation performed in 9.538125038146973 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 4, testing block current amplitude 150.0 uA
# NRV INFO: ... Iteration simulation performed in 9.469801902770996 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 5, testing block current amplitude 75.0 uA
# NRV INFO: ... Iteration simulation performed in 9.587112188339233 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 6, testing block current amplitude 37.5 uA
# NRV INFO: ... Iteration simulation performed in 9.831814050674438 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 7, testing block current amplitude 18.75 uA
# NRV INFO: ... Iteration simulation performed in 9.566044092178345 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 8, testing block current amplitude 28.125 uA
# NRV INFO: ... Iteration simulation performed in 9.891493797302246 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 9, testing block current amplitude 32.8125 uA
# NRV INFO: ... Iteration simulation performed in 9.624882936477661 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 10, testing block current amplitude 35.15625 uA
# NRV INFO: ... Iteration simulation performed in 9.441374778747559 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 11, testing block current amplitude 36.328125 uA
# NRV INFO: ... Iteration simulation performed in 9.770999908447266 s
# NRV INFO: ... Spike not blocked
# Block Threshold is: 36uA.
# Axon diameter: 8.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 9.81377625465393 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 2, testing block current amplitude 0 uA
# NRV INFO: ... Iteration simulation performed in 9.078648805618286 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 3, testing block current amplitude 300.0 uA
# NRV INFO: ... Iteration simulation performed in 9.245864868164062 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 4, testing block current amplitude 150.0 uA
# NRV INFO: ... Iteration simulation performed in 9.809866666793823 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 5, testing block current amplitude 75.0 uA
# NRV INFO: ... Iteration simulation performed in 9.49622392654419 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 6, testing block current amplitude 112.5 uA
# NRV INFO: ... Iteration simulation performed in 8.895470142364502 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 7, testing block current amplitude 93.75 uA
# NRV INFO: ... Iteration simulation performed in 9.98269534111023 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 8, testing block current amplitude 103.125 uA
# NRV INFO: ... Iteration simulation performed in 10.82400107383728 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 9, testing block current amplitude 107.8125 uA
# NRV INFO: ... Iteration simulation performed in 9.80796504020691 s
# NRV INFO: ... Spike not blocked
# Block Threshold is: 110uA.
# Axon diameter: 10.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 9.956269025802612 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 2, testing block current amplitude 0 uA
# NRV INFO: ... Iteration simulation performed in 9.638577938079834 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 3, testing block current amplitude 300.0 uA
# NRV INFO: ... Iteration simulation performed in 10.436687231063843 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 4, testing block current amplitude 450.0 uA
# NRV INFO: ... Iteration simulation performed in 10.769605159759521 s
# NRV INFO: ... Spike blocked
# NRV INFO: Iteration number 5, testing block current amplitude 375.0 uA
# NRV INFO: ... Iteration simulation performed in 11.107684850692749 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 6, testing block current amplitude 412.5 uA
# NRV INFO: ... Iteration simulation performed in 9.99029016494751 s
# NRV INFO: ... Spike not blocked
# NRV INFO: Iteration number 7, testing block current amplitude 431.25 uA
# NRV INFO: ... Iteration simulation performed in 10.061028003692627 s
# NRV INFO: ... Spike not blocked
# Block Threshold is: 440uA.
# Axon diameter: 12.0µm
# NRV INFO: Iteration number 1, testing block current amplitude 600 uA
# NRV WARNING: no loaded footprints: computation will be done anyway
# NRV INFO: ... Iteration simulation performed in 9.3685781955719 s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 53
#      50 stim_extra.add_electrode(elec_1, stim)
#      51 axon1.attach_extracellular_stimulation(stim_extra)
# ---> 53 threshold = nrv.blocking_threshold_from_axon(axon1,block_freq = KES_freq, amp_max  =max_amp,
#      54                                          amp_tol = amp_tol,t_sim= t_sim,t_start=t_start,
#      55                                          t_duration = t_duration, t_amplitude = t_amplitude,
#      56                                          b_start = 1)
#      58 print ("Block Threshold is: " + str(int(threshold)) +"uA.")
#      59 threshold_list.append(threshold)
#
# File ~/Library/CloudStorage/Dropbox/Work/Model/NRV/Example/../nrv/utils/cell/CL_simulations.py:1159, in blocking_threshold_from_axon(axon, block_freq, amp_max, amp_tol, dt, verbose, **kwargs)
#    1157 previous_amp = current_amp
#    1158 # test simulation results, update dichotomy
# -> 1159 if block(results, t_start=t_start) == False:
#    1160     if current_amp == amp_max:
#    1161         rise_warning("Maximum Stimulation Current is too Low!")
#
# File ~/Library/CloudStorage/Dropbox/Work/Model/NRV/Example/../nrv/utils/cell/CL_postprocessing.py:599, in block(my_dict, position_key, t_start, t_stop)
#     597 if "intra_stim_positions" in my_dict:
#     598     if my_dict["intra_stim_positions"] < my_dict["extracellular_electrode_x"]:
# --> 599         position_max = max_spike_position(
#     600             blocked_spike_positionlist, position_max, spike_begin="down"
#     601         )
#     603         if blocked_spike_positionlist[position_max] < 9.0 / 10 * my_dict["L"]:
#     604             return True
#
# File ~/Library/CloudStorage/Dropbox/Work/Model/NRV/Example/../nrv/utils/cell/CL_postprocessing.py:637, in max_spike_position(blocked_spike_positionlist, position_max, spike_begin)
#     635 def max_spike_position(blocked_spike_positionlist, position_max, spike_begin="down"):
#     636     if spike_begin == "down":
# --> 637         while blocked_spike_positionlist[
#     638             position_max + 1
#     639         ] >= blocked_spike_positionlist[position_max] and position_max < (
#     640             len(blocked_spike_positionlist) - 2
#     641         ):
#     642             position_max = position_max + 1
#     643         return position_max
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
